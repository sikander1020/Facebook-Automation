# %% [markdown]
# # Facebook Automation - Free Live Server 🚀
# This notebook runs your Facebook Automation project directly on Google's free cloud servers (12GB RAM) and gives you a Live Public URL.

# %%
# 1. Download the code from your GitHub
# !git clone https://github.com/sikander1020/Facebook-Automation.git
# %cd Facebook-Automation

# 2. Install FFmpeg and required Python packages
# !apt-get update && apt-get install -y ffmpeg
# !pip install -r requirements.txt

# 3. Download Cloudflare Tunnel to make the app live
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# %%
# 4. Run the App and generate a Live Public Link!
import subprocess
import time

# Start the Flask server in the background
server = subprocess.Popen(["python", "app.py"])

time.sleep(3) # Wait for server to start

# Expose the server to the internet using Cloudflare
print("\n=======================================================")
print("Generating your LIVE URL... Please wait 5-10 seconds.")
print("Click the link ending in .trycloudflare.com below! \n")

# !cloudflared tunnel --url http://127.0.0.1:7860
